# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torchvision.utils import save_image

# %%
#Loadung the model vgg19 that will serve as the base model
model=models.vgg19(pretrained=True).features
#Assigning the GPU to the variable device
device=torch.device("cuda" if (torch.cuda.is_available()) else 'cpu')
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
#defing a function that will load the image and perform the required preprocessing and put it on the GPU
def image_loader(path):
    image=Image.open(path)
    #defining the image transformation steps to be performed before feeding them to the model
    loader=transforms.Compose([transforms.Resize((512,512)), transforms.ToTensor()])
    #The preprocessing steps involves resizing the image and then converting it to a tensor
    image=loader(image).unsqueeze(0)
    return image.to(device,torch.float)

#Loading the original and the style image
original_image=image_loader('/content/Technological_Institute_of_the_Philippines_Quezon_City.jpg')
style_image=image_loader('/content/Van-Gogh-The-Starry-Night-adult-coloring-page-1.jpg')

#Creating the generated image from the original image
generated_image=original_image.clone().requires_grad_(True)

# %%
#Defining a class that for the model
class VGG(nn.Module):
    def __init__(self):
        super(VGG,self).__init__()
        self.req_features= ['0','5','10','19','28'] 
        #Since we need only the 5 layers in the model so we will be dropping all the rest layers from the features of the model
        self.model=models.vgg19(pretrained=True).features[:29] #model will contain the first 29 layers
    
   
    #x holds the input tensor(image) that will be feeded to each layer
    def forward(self,x):
        #initialize an array that wil hold the activations from the chosen layers
        features=[]
        #Iterate over all the layers of the mode
        for layer_num,layer in enumerate(self.model):
            #activation of the layer will stored in x
            x=layer(x)
            #appending the activation of the selected layers and return the feature array
            if (str(layer_num) in self.req_features):
                features.append(x)
                
        return features

# %%
def calc_content_loss(gen_feat,orig_feat):
    #calculating the content loss of each layer by calculating the MSE between the content and generated features and adding it to content loss
    content_l=torch.mean((gen_feat-orig_feat)**2)
    return content_l

# %%
def calc_style_loss(gen,style):
    #Calculating the gram matrix for the style and the generated image
    batch_size,channel,height,width=gen.shape

    G=torch.mm(gen.view(channel,height*width),gen.view(channel,height*width).t())
    A=torch.mm(style.view(channel,height*width),style.view(channel,height*width).t())
        
    #Calcultating the style loss of each layer by calculating the MSE between the gram matrix of the style image and the generated image and adding it to style loss
    style_l=torch.mean((G-A)**2)
    return style_l

# %%
def calculate_loss(gen_features, orig_feautes, style_featues):
    style_loss=content_loss=0
    for gen,cont,style in zip(gen_features,orig_feautes,style_featues):
        #extracting the dimensions from the generated image
        content_loss+=calc_content_loss(gen,cont)
        style_loss+=calc_style_loss(gen,style)
    
    #calculating the total loss of e th epoch
    total_loss=alpha*content_loss + beta*style_loss 
    return total_loss

# %%
#Load the model to the GPU
model=VGG().to(device).eval() 

#initialize the paramerters required for fitting the model
epoch=7000
lr=0.004
alpha=8
beta=70

#using adam optimizer and it will update the generated image not the model parameter 
optimizer=optim.Adam([generated_image],lr=lr)

# %%
#iterating for 1000 times
for e in range (epoch):
    #extracting the features of generated, content and the original required for calculating the loss
    gen_features=model(generated_image)
    orig_feautes=model(original_image)
    style_featues=model(style_image)
    
    #iterating over the activation of each layer and calculate the loss and add it to the content and the style loss
    total_loss=calculate_loss(gen_features, orig_feautes, style_featues)
    #optimize the pixel values of the generated image and backpropagate the loss
    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step()
    #print the image and save it after each 100 epoch
    if(e/100):
        print(total_loss)
        
        save_image(generated_image,"Johnsen.png")
# Out:
# tensor(7.1377e+10, grad_fn=<AddBackward0>)
# tensor(6.6084e+10, grad_fn=<AddBackward0>)
# tensor(6.0334e+10, grad_fn=<AddBackward0>)
# tensor(5.4316e+10, grad_fn=<AddBackward0>)
# tensor(4.8283e+10, grad_fn=<AddBackward0>)
# tensor(4.2448e+10, grad_fn=<AddBackward0>)
# tensor(3.6977e+10, grad_fn=<AddBackward0>)
# tensor(3.1990e+10, grad_fn=<AddBackward0>)
# tensor(2.7570e+10, grad_fn=<AddBackward0>)
# tensor(2.3777e+10, grad_fn=<AddBackward0>)
# tensor(2.0609e+10, grad_fn=<AddBackward0>)
# tensor(1.8025e+10, grad_fn=<AddBackward0>)
# tensor(1.5957e+10, grad_fn=<AddBackward0>)
# tensor(1.4323e+10, grad_fn=<AddBackward0>)
# tensor(1.3031e+10, grad_fn=<AddBackward0>)
# tensor(1.1981e+10, grad_fn=<AddBackward0>)
# tensor(1.1071e+10, grad_fn=<AddBackward0>)
# tensor(1.0228e+10, grad_fn=<AddBackward0>)
# tensor(9.4122e+09, grad_fn=<AddBackward0>)
# tensor(8.6169e+09, grad_fn=<AddBackward0>)
# tensor(7.8565e+09, grad_fn=<AddBackward0>)
# tensor(7.1511e+09, grad_fn=<AddBackward0>)
# tensor(6.5150e+09, grad_fn=<AddBackward0>)
# tensor(5.9556e+09, grad_fn=<AddBackward0>)
# tensor(5.4760e+09, grad_fn=<AddBackward0>)
# tensor(5.0746e+09, grad_fn=<AddBackward0>)
# tensor(4.7432e+09, grad_fn=<AddBackward0>)
# tensor(4.4691e+09, grad_fn=<AddBackward0>)
# tensor(4.2381e+09, grad_fn=<AddBackward0>)
# tensor(4.0369e+09, grad_fn=<AddBackward0>)
# tensor(3.8542e+09, grad_fn=<AddBackward0>)
# tensor(3.6828e+09, grad_fn=<AddBackward0>)
# tensor(3.5192e+09, grad_fn=<AddBackward0>)
# tensor(3.3631e+09, grad_fn=<AddBackward0>)
# tensor(3.2160e+09, grad_fn=<AddBackward0>)
# tensor(3.0792e+09, grad_fn=<AddBackward0>)
# tensor(2.9531e+09, grad_fn=<AddBackward0>)
# tensor(2.8375e+09, grad_fn=<AddBackward0>)
# tensor(2.7311e+09, grad_fn=<AddBackward0>)
# tensor(2.6321e+09, grad_fn=<AddBackward0>)
# tensor(2.5393e+09, grad_fn=<AddBackward0>)
# tensor(2.4518e+09, grad_fn=<AddBackward0>)
# tensor(2.3691e+09, grad_fn=<AddBackward0>)
# tensor(2.2912e+09, grad_fn=<AddBackward0>)
# tensor(2.2178e+09, grad_fn=<AddBackward0>)
# tensor(2.1485e+09, grad_fn=<AddBackward0>)
# tensor(2.0826e+09, grad_fn=<AddBackward0>)
# tensor(2.0199e+09, grad_fn=<AddBackward0>)
# tensor(1.9602e+09, grad_fn=<AddBackward0>)
# tensor(1.9036e+09, grad_fn=<AddBackward0>)
# tensor(1.8501e+09, grad_fn=<AddBackward0>)
# tensor(1.7997e+09, grad_fn=<AddBackward0>)
# tensor(1.7523e+09, grad_fn=<AddBackward0>)
# tensor(1.7076e+09, grad_fn=<AddBackward0>)
# tensor(1.6652e+09, grad_fn=<AddBackward0>)
# tensor(1.6250e+09, grad_fn=<AddBackward0>)
# tensor(1.5866e+09, grad_fn=<AddBackward0>)
# tensor(1.5501e+09, grad_fn=<AddBackward0>)
# tensor(1.5153e+09, grad_fn=<AddBackward0>)
# tensor(1.4823e+09, grad_fn=<AddBackward0>)
# tensor(1.4508e+09, grad_fn=<AddBackward0>)
# tensor(1.4208e+09, grad_fn=<AddBackward0>)
# tensor(1.3921e+09, grad_fn=<AddBackward0>)
# tensor(1.3645e+09, grad_fn=<AddBackward0>)
# tensor(1.3381e+09, grad_fn=<AddBackward0>)
# tensor(1.3127e+09, grad_fn=<AddBackward0>)
# tensor(1.2882e+09, grad_fn=<AddBackward0>)
# tensor(1.2646e+09, grad_fn=<AddBackward0>)
# tensor(1.2417e+09, grad_fn=<AddBackward0>)
# tensor(1.2197e+09, grad_fn=<AddBackward0>)
# tensor(1.1984e+09, grad_fn=<AddBackward0>)
# tensor(1.1779e+09, grad_fn=<AddBackward0>)
# tensor(1.1582e+09, grad_fn=<AddBackward0>)
# tensor(1.1392e+09, grad_fn=<AddBackward0>)
# tensor(1.1208e+09, grad_fn=<AddBackward0>)
# tensor(1.1031e+09, grad_fn=<AddBackward0>)
# tensor(1.0859e+09, grad_fn=<AddBackward0>)
# tensor(1.0692e+09, grad_fn=<AddBackward0>)
# tensor(1.0530e+09, grad_fn=<AddBackward0>)
# tensor(1.0374e+09, grad_fn=<AddBackward0>)
# tensor(1.0222e+09, grad_fn=<AddBackward0>)
# tensor(1.0075e+09, grad_fn=<AddBackward0>)
# tensor(9.9329e+08, grad_fn=<AddBackward0>)
# tensor(9.7947e+08, grad_fn=<AddBackward0>)
# tensor(9.6604e+08, grad_fn=<AddBackward0>)
# tensor(9.5297e+08, grad_fn=<AddBackward0>)
# tensor(9.4026e+08, grad_fn=<AddBackward0>)
# tensor(9.2790e+08, grad_fn=<AddBackward0>)
# tensor(9.1588e+08, grad_fn=<AddBackward0>)
# tensor(9.0418e+08, grad_fn=<AddBackward0>)
# tensor(8.9279e+08, grad_fn=<AddBackward0>)
# tensor(8.8169e+08, grad_fn=<AddBackward0>)
# tensor(8.7089e+08, grad_fn=<AddBackward0>)
# tensor(8.6037e+08, grad_fn=<AddBackward0>)
# tensor(8.5010e+08, grad_fn=<AddBackward0>)
# tensor(8.4008e+08, grad_fn=<AddBackward0>)
# tensor(8.3031e+08, grad_fn=<AddBackward0>)
# tensor(8.2077e+08, grad_fn=<AddBackward0>)
# tensor(8.1145e+08, grad_fn=<AddBackward0>)
# tensor(8.0235e+08, grad_fn=<AddBackward0>)
# tensor(7.9346e+08, grad_fn=<AddBackward0>)
# tensor(7.8477e+08, grad_fn=<AddBackward0>)
# tensor(7.7628e+08, grad_fn=<AddBackward0>)
# tensor(7.6797e+08, grad_fn=<AddBackward0>)
# tensor(7.5985e+08, grad_fn=<AddBackward0>)
# tensor(7.5191e+08, grad_fn=<AddBackward0>)
# tensor(7.4413e+08, grad_fn=<AddBackward0>)
# tensor(7.3653e+08, grad_fn=<AddBackward0>)
# tensor(7.2909e+08, grad_fn=<AddBackward0>)
# tensor(7.2180e+08, grad_fn=<AddBackward0>)
# tensor(7.1467e+08, grad_fn=<AddBackward0>)
# tensor(7.0768e+08, grad_fn=<AddBackward0>)
# tensor(7.0084e+08, grad_fn=<AddBackward0>)
# tensor(6.9413e+08, grad_fn=<AddBackward0>)
# tensor(6.8756e+08, grad_fn=<AddBackward0>)
# tensor(6.8113e+08, grad_fn=<AddBackward0>)
# tensor(6.7481e+08, grad_fn=<AddBackward0>)
# tensor(6.6861e+08, grad_fn=<AddBackward0>)
# tensor(6.6253e+08, grad_fn=<AddBackward0>)
# tensor(6.5657e+08, grad_fn=<AddBackward0>)
# tensor(6.5072e+08, grad_fn=<AddBackward0>)
# tensor(6.4497e+08, grad_fn=<AddBackward0>)
# tensor(6.3932e+08, grad_fn=<AddBackward0>)
# tensor(6.3378e+08, grad_fn=<AddBackward0>)
# tensor(6.2833e+08, grad_fn=<AddBackward0>)
# tensor(6.2298e+08, grad_fn=<AddBackward0>)
# tensor(6.1772e+08, grad_fn=<AddBackward0>)
# tensor(6.1255e+08, grad_fn=<AddBackward0>)
# tensor(6.0746e+08, grad_fn=<AddBackward0>)
# tensor(6.0246e+08, grad_fn=<AddBackward0>)
# tensor(5.9753e+08, grad_fn=<AddBackward0>)
# tensor(5.9269e+08, grad_fn=<AddBackward0>)
# tensor(5.8794e+08, grad_fn=<AddBackward0>)
# tensor(5.8326e+08, grad_fn=<AddBackward0>)
# tensor(5.7866e+08, grad_fn=<AddBackward0>)
# tensor(5.7413e+08, grad_fn=<AddBackward0>)
# tensor(5.6967e+08, grad_fn=<AddBackward0>)
# tensor(5.6528e+08, grad_fn=<AddBackward0>)
# tensor(5.6096e+08, grad_fn=<AddBackward0>)
# tensor(5.5670e+08, grad_fn=<AddBackward0>)
# tensor(5.5251e+08, grad_fn=<AddBackward0>)
# tensor(5.4837e+08, grad_fn=<AddBackward0>)
# tensor(5.4430e+08, grad_fn=<AddBackward0>)
# tensor(5.4028e+08, grad_fn=<AddBackward0>)
# tensor(5.3632e+08, grad_fn=<AddBackward0>)
# tensor(5.3242e+08, grad_fn=<AddBackward0>)
# tensor(5.2857e+08, grad_fn=<AddBackward0>)
# tensor(5.2478e+08, grad_fn=<AddBackward0>)
# tensor(5.2104e+08, grad_fn=<AddBackward0>)
# tensor(5.1735e+08, grad_fn=<AddBackward0>)
# tensor(5.1371e+08, grad_fn=<AddBackward0>)
# tensor(5.1012e+08, grad_fn=<AddBackward0>)
# tensor(5.0658e+08, grad_fn=<AddBackward0>)
# tensor(5.0308e+08, grad_fn=<AddBackward0>)
# tensor(4.9964e+08, grad_fn=<AddBackward0>)
# tensor(4.9624e+08, grad_fn=<AddBackward0>)
# tensor(4.9288e+08, grad_fn=<AddBackward0>)
# tensor(4.8957e+08, grad_fn=<AddBackward0>)
# tensor(4.8629e+08, grad_fn=<AddBackward0>)
# tensor(4.8306e+08, grad_fn=<AddBackward0>)
# tensor(4.7987e+08, grad_fn=<AddBackward0>)
# tensor(4.7672e+08, grad_fn=<AddBackward0>)
# tensor(4.7362e+08, grad_fn=<AddBackward0>)
# tensor(4.7054e+08, grad_fn=<AddBackward0>)
# tensor(4.6751e+08, grad_fn=<AddBackward0>)
# tensor(4.6452e+08, grad_fn=<AddBackward0>)
# tensor(4.6156e+08, grad_fn=<AddBackward0>)
# tensor(4.5864e+08, grad_fn=<AddBackward0>)
# tensor(4.5575e+08, grad_fn=<AddBackward0>)
# tensor(4.5290e+08, grad_fn=<AddBackward0>)
# tensor(4.5008e+08, grad_fn=<AddBackward0>)
# tensor(4.4729e+08, grad_fn=<AddBackward0>)
# tensor(4.4454e+08, grad_fn=<AddBackward0>)
# tensor(4.4182e+08, grad_fn=<AddBackward0>)
# tensor(4.3914e+08, grad_fn=<AddBackward0>)
# tensor(4.3648e+08, grad_fn=<AddBackward0>)
# tensor(4.3385e+08, grad_fn=<AddBackward0>)
# tensor(4.3125e+08, grad_fn=<AddBackward0>)
# tensor(4.2867e+08, grad_fn=<AddBackward0>)
# tensor(4.2613e+08, grad_fn=<AddBackward0>)
# tensor(4.2361e+08, grad_fn=<AddBackward0>)
# tensor(4.2112e+08, grad_fn=<AddBackward0>)
# tensor(4.1865e+08, grad_fn=<AddBackward0>)
# tensor(4.1621e+08, grad_fn=<AddBackward0>)
# tensor(4.1380e+08, grad_fn=<AddBackward0>)
# tensor(4.1141e+08, grad_fn=<AddBackward0>)
# tensor(4.0905e+08, grad_fn=<AddBackward0>)
# tensor(4.0671e+08, grad_fn=<AddBackward0>)
# tensor(4.0440e+08, grad_fn=<AddBackward0>)
# tensor(4.0211e+08, grad_fn=<AddBackward0>)
# tensor(3.9985e+08, grad_fn=<AddBackward0>)
# tensor(3.9760e+08, grad_fn=<AddBackward0>)
# tensor(3.9538e+08, grad_fn=<AddBackward0>)
# tensor(3.9319e+08, grad_fn=<AddBackward0>)
# tensor(3.9101e+08, grad_fn=<AddBackward0>)
# tensor(3.8886e+08, grad_fn=<AddBackward0>)
# tensor(3.8673e+08, grad_fn=<AddBackward0>)
# tensor(3.8462e+08, grad_fn=<AddBackward0>)
# tensor(3.8253e+08, grad_fn=<AddBackward0>)
# tensor(3.8046e+08, grad_fn=<AddBackward0>)
# tensor(3.7841e+08, grad_fn=<AddBackward0>)
# tensor(3.7639e+08, grad_fn=<AddBackward0>)
# tensor(3.7438e+08, grad_fn=<AddBackward0>)
# tensor(3.7239e+08, grad_fn=<AddBackward0>)
# tensor(3.7042e+08, grad_fn=<AddBackward0>)
# tensor(3.6847e+08, grad_fn=<AddBackward0>)
# tensor(3.6654e+08, grad_fn=<AddBackward0>)
# tensor(3.6462e+08, grad_fn=<AddBackward0>)
# tensor(3.6273e+08, grad_fn=<AddBackward0>)
# tensor(3.6085e+08, grad_fn=<AddBackward0>)
# tensor(3.5899e+08, grad_fn=<AddBackward0>)
# tensor(3.5715e+08, grad_fn=<AddBackward0>)
# tensor(3.5533e+08, grad_fn=<AddBackward0>)
# tensor(3.5352e+08, grad_fn=<AddBackward0>)
# tensor(3.5172e+08, grad_fn=<AddBackward0>)
# tensor(3.4995e+08, grad_fn=<AddBackward0>)
# tensor(3.4819e+08, grad_fn=<AddBackward0>)
# tensor(3.4644e+08, grad_fn=<AddBackward0>)
# tensor(3.4471e+08, grad_fn=<AddBackward0>)
# tensor(3.4300e+08, grad_fn=<AddBackward0>)
# tensor(3.4130e+08, grad_fn=<AddBackward0>)
# tensor(3.3962e+08, grad_fn=<AddBackward0>)
# tensor(3.3795e+08, grad_fn=<AddBackward0>)
# tensor(3.3630e+08, grad_fn=<AddBackward0>)
# tensor(3.3466e+08, grad_fn=<AddBackward0>)
# tensor(3.3304e+08, grad_fn=<AddBackward0>)
# tensor(3.3143e+08, grad_fn=<AddBackward0>)
# tensor(3.2984e+08, grad_fn=<AddBackward0>)
# tensor(3.2826e+08, grad_fn=<AddBackward0>)
# tensor(3.2670e+08, grad_fn=<AddBackward0>)
# tensor(3.2515e+08, grad_fn=<AddBackward0>)
# tensor(3.2361e+08, grad_fn=<AddBackward0>)
# tensor(3.2209e+08, grad_fn=<AddBackward0>)
# tensor(3.2058e+08, grad_fn=<AddBackward0>)
# tensor(3.1908e+08, grad_fn=<AddBackward0>)
# tensor(3.1759e+08, grad_fn=<AddBackward0>)
# tensor(3.1612e+08, grad_fn=<AddBackward0>)
# tensor(3.1465e+08, grad_fn=<AddBackward0>)
# tensor(3.1321e+08, grad_fn=<AddBackward0>)
# tensor(3.1177e+08, grad_fn=<AddBackward0>)
# tensor(3.1035e+08, grad_fn=<AddBackward0>)
# tensor(3.0893e+08, grad_fn=<AddBackward0>)
# tensor(3.0753e+08, grad_fn=<AddBackward0>)
# tensor(3.0615e+08, grad_fn=<AddBackward0>)
# tensor(3.0477e+08, grad_fn=<AddBackward0>)
# tensor(3.0341e+08, grad_fn=<AddBackward0>)
# tensor(3.0206e+08, grad_fn=<AddBackward0>)
# tensor(3.0072e+08, grad_fn=<AddBackward0>)
# tensor(2.9939e+08, grad_fn=<AddBackward0>)
# tensor(2.9807e+08, grad_fn=<AddBackward0>)
# tensor(2.9676e+08, grad_fn=<AddBackward0>)
# tensor(2.9547e+08, grad_fn=<AddBackward0>)
# tensor(2.9418e+08, grad_fn=<AddBackward0>)
# tensor(2.9291e+08, grad_fn=<AddBackward0>)
# tensor(2.9164e+08, grad_fn=<AddBackward0>)
# tensor(2.9039e+08, grad_fn=<AddBackward0>)
# tensor(2.8915e+08, grad_fn=<AddBackward0>)
# tensor(2.8791e+08, grad_fn=<AddBackward0>)
# tensor(2.8669e+08, grad_fn=<AddBackward0>)
# tensor(2.8548e+08, grad_fn=<AddBackward0>)
# tensor(2.8427e+08, grad_fn=<AddBackward0>)
# tensor(2.8308e+08, grad_fn=<AddBackward0>)
# tensor(2.8190e+08, grad_fn=<AddBackward0>)
# tensor(2.8072e+08, grad_fn=<AddBackward0>)
# tensor(2.7956e+08, grad_fn=<AddBackward0>)
# tensor(2.7840e+08, grad_fn=<AddBackward0>)
# tensor(2.7726e+08, grad_fn=<AddBackward0>)
# tensor(2.7612e+08, grad_fn=<AddBackward0>)
# tensor(2.7499e+08, grad_fn=<AddBackward0>)
# tensor(2.7387e+08, grad_fn=<AddBackward0>)
# tensor(2.7276e+08, grad_fn=<AddBackward0>)
# tensor(2.7166e+08, grad_fn=<AddBackward0>)
# tensor(2.7056e+08, grad_fn=<AddBackward0>)
# tensor(2.6948e+08, grad_fn=<AddBackward0>)
# tensor(2.6840e+08, grad_fn=<AddBackward0>)
# tensor(2.6733e+08, grad_fn=<AddBackward0>)
# tensor(2.6627e+08, grad_fn=<AddBackward0>)
# tensor(2.6522e+08, grad_fn=<AddBackward0>)
# tensor(2.6417e+08, grad_fn=<AddBackward0>)
# tensor(2.6314e+08, grad_fn=<AddBackward0>)
# tensor(2.6211e+08, grad_fn=<AddBackward0>)
# tensor(2.6109e+08, grad_fn=<AddBackward0>)
# tensor(2.6008e+08, grad_fn=<AddBackward0>)
# tensor(2.5907e+08, grad_fn=<AddBackward0>)
# tensor(2.5808e+08, grad_fn=<AddBackward0>)
# tensor(2.5709e+08, grad_fn=<AddBackward0>)
# tensor(2.5610e+08, grad_fn=<AddBackward0>)
# tensor(2.5513e+08, grad_fn=<AddBackward0>)
# tensor(2.5416e+08, grad_fn=<AddBackward0>)
# tensor(2.5320e+08, grad_fn=<AddBackward0>)
# tensor(2.5225e+08, grad_fn=<AddBackward0>)
# tensor(2.5130e+08, grad_fn=<AddBackward0>)
# tensor(2.5037e+08, grad_fn=<AddBackward0>)
# tensor(2.4943e+08, grad_fn=<AddBackward0>)
# tensor(2.4851e+08, grad_fn=<AddBackward0>)
# tensor(2.4759e+08, grad_fn=<AddBackward0>)
# tensor(2.4669e+08, grad_fn=<AddBackward0>)
# tensor(2.4578e+08, grad_fn=<AddBackward0>)
# tensor(2.4489e+08, grad_fn=<AddBackward0>)
# tensor(2.4400e+08, grad_fn=<AddBackward0>)
# tensor(2.4312e+08, grad_fn=<AddBackward0>)
# tensor(2.4224e+08, grad_fn=<AddBackward0>)
# tensor(2.4137e+08, grad_fn=<AddBackward0>)
# tensor(2.4051e+08, grad_fn=<AddBackward0>)
# tensor(2.3966e+08, grad_fn=<AddBackward0>)
# tensor(2.3881e+08, grad_fn=<AddBackward0>)
# tensor(2.3797e+08, grad_fn=<AddBackward0>)
# tensor(2.3713e+08, grad_fn=<AddBackward0>)
# tensor(2.3630e+08, grad_fn=<AddBackward0>)
# tensor(2.3547e+08, grad_fn=<AddBackward0>)
# tensor(2.3466e+08, grad_fn=<AddBackward0>)
# tensor(2.3385e+08, grad_fn=<AddBackward0>)
# tensor(2.3304e+08, grad_fn=<AddBackward0>)
# tensor(2.3224e+08, grad_fn=<AddBackward0>)
# tensor(2.3145e+08, grad_fn=<AddBackward0>)
# tensor(2.3066e+08, grad_fn=<AddBackward0>)
# tensor(2.2988e+08, grad_fn=<AddBackward0>)
# tensor(2.2910e+08, grad_fn=<AddBackward0>)
# tensor(2.2833e+08, grad_fn=<AddBackward0>)
# tensor(2.2756e+08, grad_fn=<AddBackward0>)
# tensor(2.2680e+08, grad_fn=<AddBackward0>)
# tensor(2.2605e+08, grad_fn=<AddBackward0>)
# tensor(2.2530e+08, grad_fn=<AddBackward0>)
# tensor(2.2455e+08, grad_fn=<AddBackward0>)
# tensor(2.2381e+08, grad_fn=<AddBackward0>)
# tensor(2.2308e+08, grad_fn=<AddBackward0>)
# tensor(2.2235e+08, grad_fn=<AddBackward0>)
# tensor(2.2163e+08, grad_fn=<AddBackward0>)
# tensor(2.2091e+08, grad_fn=<AddBackward0>)
# tensor(2.2020e+08, grad_fn=<AddBackward0>)
# tensor(2.1949e+08, grad_fn=<AddBackward0>)
# tensor(2.1878e+08, grad_fn=<AddBackward0>)
# tensor(2.1808e+08, grad_fn=<AddBackward0>)
# tensor(2.1739e+08, grad_fn=<AddBackward0>)
# tensor(2.1670e+08, grad_fn=<AddBackward0>)
# tensor(2.1602e+08, grad_fn=<AddBackward0>)
# tensor(2.1534e+08, grad_fn=<AddBackward0>)
# tensor(2.1467e+08, grad_fn=<AddBackward0>)
# tensor(2.1400e+08, grad_fn=<AddBackward0>)
# tensor(2.1333e+08, grad_fn=<AddBackward0>)
# tensor(2.1267e+08, grad_fn=<AddBackward0>)
# tensor(2.1202e+08, grad_fn=<AddBackward0>)
# tensor(2.1137e+08, grad_fn=<AddBackward0>)
# tensor(2.1072e+08, grad_fn=<AddBackward0>)
# tensor(2.1008e+08, grad_fn=<AddBackward0>)
# tensor(2.0944e+08, grad_fn=<AddBackward0>)
# tensor(2.0881e+08, grad_fn=<AddBackward0>)
# tensor(2.0818e+08, grad_fn=<AddBackward0>)
# tensor(2.0755e+08, grad_fn=<AddBackward0>)
# tensor(2.0693e+08, grad_fn=<AddBackward0>)
# tensor(2.0631e+08, grad_fn=<AddBackward0>)
# tensor(2.0570e+08, grad_fn=<AddBackward0>)
# tensor(2.0509e+08, grad_fn=<AddBackward0>)
# tensor(2.0449e+08, grad_fn=<AddBackward0>)
# tensor(2.0388e+08, grad_fn=<AddBackward0>)
# tensor(2.0329e+08, grad_fn=<AddBackward0>)
# tensor(2.0269e+08, grad_fn=<AddBackward0>)
# tensor(2.0210e+08, grad_fn=<AddBackward0>)
# tensor(2.0152e+08, grad_fn=<AddBackward0>)
# tensor(2.0093e+08, grad_fn=<AddBackward0>)
# tensor(2.0036e+08, grad_fn=<AddBackward0>)
# tensor(1.9978e+08, grad_fn=<AddBackward0>)
# tensor(1.9921e+08, grad_fn=<AddBackward0>)
# tensor(1.9864e+08, grad_fn=<AddBackward0>)
# tensor(1.9808e+08, grad_fn=<AddBackward0>)
# tensor(1.9752e+08, grad_fn=<AddBackward0>)
# tensor(1.9696e+08, grad_fn=<AddBackward0>)
# tensor(1.9641e+08, grad_fn=<AddBackward0>)
# tensor(1.9586e+08, grad_fn=<AddBackward0>)
# tensor(1.9532e+08, grad_fn=<AddBackward0>)
# tensor(1.9477e+08, grad_fn=<AddBackward0>)
# tensor(1.9424e+08, grad_fn=<AddBackward0>)
# tensor(1.9370e+08, grad_fn=<AddBackward0>)
# tensor(1.9317e+08, grad_fn=<AddBackward0>)
# tensor(1.9264e+08, grad_fn=<AddBackward0>)
# tensor(1.9212e+08, grad_fn=<AddBackward0>)
# tensor(1.9160e+08, grad_fn=<AddBackward0>)
# tensor(1.9108e+08, grad_fn=<AddBackward0>)
# tensor(1.9057e+08, grad_fn=<AddBackward0>)
# tensor(1.9006e+08, grad_fn=<AddBackward0>)
# tensor(1.8955e+08, grad_fn=<AddBackward0>)
# tensor(1.8905e+08, grad_fn=<AddBackward0>)
# tensor(1.8855e+08, grad_fn=<AddBackward0>)
# tensor(1.8805e+08, grad_fn=<AddBackward0>)
# tensor(1.8755e+08, grad_fn=<AddBackward0>)
# tensor(1.8706e+08, grad_fn=<AddBackward0>)
# tensor(1.8658e+08, grad_fn=<AddBackward0>)
# tensor(1.8609e+08, grad_fn=<AddBackward0>)
# tensor(1.8561e+08, grad_fn=<AddBackward0>)
# tensor(1.8513e+08, grad_fn=<AddBackward0>)
# tensor(1.8466e+08, grad_fn=<AddBackward0>)
# tensor(1.8418e+08, grad_fn=<AddBackward0>)
# tensor(1.8371e+08, grad_fn=<AddBackward0>)
# tensor(1.8325e+08, grad_fn=<AddBackward0>)
# tensor(1.8278e+08, grad_fn=<AddBackward0>)
# tensor(1.8232e+08, grad_fn=<AddBackward0>)
# tensor(1.8187e+08, grad_fn=<AddBackward0>)
# tensor(1.8141e+08, grad_fn=<AddBackward0>)
# tensor(1.8096e+08, grad_fn=<AddBackward0>)
# tensor(1.8051e+08, grad_fn=<AddBackward0>)
# tensor(1.8006e+08, grad_fn=<AddBackward0>)
# tensor(1.7962e+08, grad_fn=<AddBackward0>)
# tensor(1.7918e+08, grad_fn=<AddBackward0>)
# tensor(1.7874e+08, grad_fn=<AddBackward0>)
# tensor(1.7830e+08, grad_fn=<AddBackward0>)
# tensor(1.7787e+08, grad_fn=<AddBackward0>)
# tensor(1.7744e+08, grad_fn=<AddBackward0>)
# tensor(1.7701e+08, grad_fn=<AddBackward0>)
# tensor(1.7658e+08, grad_fn=<AddBackward0>)
# tensor(1.7616e+08, grad_fn=<AddBackward0>)
# tensor(1.7574e+08, grad_fn=<AddBackward0>)
# tensor(1.7532e+08, grad_fn=<AddBackward0>)
# tensor(1.7491e+08, grad_fn=<AddBackward0>)
# tensor(1.7449e+08, grad_fn=<AddBackward0>)
# tensor(1.7408e+08, grad_fn=<AddBackward0>)
# tensor(1.7367e+08, grad_fn=<AddBackward0>)
# tensor(1.7327e+08, grad_fn=<AddBackward0>)
# tensor(1.7287e+08, grad_fn=<AddBackward0>)
# tensor(1.7246e+08, grad_fn=<AddBackward0>)
# tensor(1.7207e+08, grad_fn=<AddBackward0>)
# tensor(1.7167e+08, grad_fn=<AddBackward0>)
# tensor(1.7128e+08, grad_fn=<AddBackward0>)
# tensor(1.7088e+08, grad_fn=<AddBackward0>)
# tensor(1.7049e+08, grad_fn=<AddBackward0>)
# tensor(1.7011e+08, grad_fn=<AddBackward0>)
# tensor(1.6972e+08, grad_fn=<AddBackward0>)
# tensor(1.6934e+08, grad_fn=<AddBackward0>)
# tensor(1.6896e+08, grad_fn=<AddBackward0>)
# tensor(1.6858e+08, grad_fn=<AddBackward0>)
# tensor(1.6820e+08, grad_fn=<AddBackward0>)
# tensor(1.6783e+08, grad_fn=<AddBackward0>)
# tensor(1.6746e+08, grad_fn=<AddBackward0>)
# tensor(1.6709e+08, grad_fn=<AddBackward0>)
# tensor(1.6672e+08, grad_fn=<AddBackward0>)
# tensor(1.6635e+08, grad_fn=<AddBackward0>)
# tensor(1.6599e+08, grad_fn=<AddBackward0>)
# tensor(1.6563e+08, grad_fn=<AddBackward0>)
# tensor(1.6527e+08, grad_fn=<AddBackward0>)
# tensor(1.6491e+08, grad_fn=<AddBackward0>)
# tensor(1.6455e+08, grad_fn=<AddBackward0>)
# tensor(1.6420e+08, grad_fn=<AddBackward0>)
# tensor(1.6385e+08, grad_fn=<AddBackward0>)
# tensor(1.6350e+08, grad_fn=<AddBackward0>)
# tensor(1.6315e+08, grad_fn=<AddBackward0>)
# tensor(1.6280e+08, grad_fn=<AddBackward0>)
# tensor(1.6246e+08, grad_fn=<AddBackward0>)
# tensor(1.6212e+08, grad_fn=<AddBackward0>)
# tensor(1.6178e+08, grad_fn=<AddBackward0>)
# tensor(1.6144e+08, grad_fn=<AddBackward0>)
# tensor(1.6110e+08, grad_fn=<AddBackward0>)
# tensor(1.6076e+08, grad_fn=<AddBackward0>)
# tensor(1.6043e+08, grad_fn=<AddBackward0>)
# tensor(1.6010e+08, grad_fn=<AddBackward0>)
# tensor(1.5977e+08, grad_fn=<AddBackward0>)
# tensor(1.5944e+08, grad_fn=<AddBackward0>)
# tensor(1.5911e+08, grad_fn=<AddBackward0>)
# tensor(1.5879e+08, grad_fn=<AddBackward0>)
# tensor(1.5846e+08, grad_fn=<AddBackward0>)
# tensor(1.5814e+08, grad_fn=<AddBackward0>)
# tensor(1.5782e+08, grad_fn=<AddBackward0>)
# tensor(1.5750e+08, grad_fn=<AddBackward0>)
# tensor(1.5718e+08, grad_fn=<AddBackward0>)
# tensor(1.5687e+08, grad_fn=<AddBackward0>)
# tensor(1.5655e+08, grad_fn=<AddBackward0>)
# tensor(1.5624e+08, grad_fn=<AddBackward0>)
# tensor(1.5593e+08, grad_fn=<AddBackward0>)
# tensor(1.5562e+08, grad_fn=<AddBackward0>)
# tensor(1.5531e+08, grad_fn=<AddBackward0>)
# tensor(1.5500e+08, grad_fn=<AddBackward0>)
# tensor(1.5470e+08, grad_fn=<AddBackward0>)
# tensor(1.5440e+08, grad_fn=<AddBackward0>)
# tensor(1.5409e+08, grad_fn=<AddBackward0>)
# tensor(1.5379e+08, grad_fn=<AddBackward0>)
# tensor(1.5349e+08, grad_fn=<AddBackward0>)
# tensor(1.5320e+08, grad_fn=<AddBackward0>)
# tensor(1.5290e+08, grad_fn=<AddBackward0>)
